# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

img = cv2.imread("dog_backpack.png")
#img = np.zeros((500, 500), np.uint8)

# Uncomment below lines if you want to draw on the image
#cv2.rectangle(img, (0, 250), (500, 500), (255), -1)
#cv2.rectangle(img, (0, 125), (250, 250), (127), -1)

b, g, r = cv2.split(img)

#cv2.imshow("b", b)
#cv2.imshow("g", g)
#cv2.imshow("r", r)
#plt.hist(img.ravel(), 255, [0, 255])
#plt.hist(b.ravel(), 255, [0, 255])
#plt.hist(g.ravel(), 255, [0, 255])
#plt.hist(r.ravel(), 255, [0, 255])
#plt.plot(hist)

plt.plot(cv2.calcHist([b], [0], None, [256], [0, 256]), label="Blue")
plt.plot(cv2.calcHist([g], [0], None, [256], [0, 256]), label="Green")
plt.plot(cv2.calcHist([r], [0], None, [256], [0, 256]), label="Red")
plt.legend()


plt.show()

cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
